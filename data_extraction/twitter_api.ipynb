# %%
import twitter

# %%
api = twitter.Api(consumer_key='RHJrJtwXpyvhWDtEwDnMH9rZ2',
                  consumer_secret='SKqFJ4gNulezD5ooLhux481ySs6rYOHbxeyQOOev8XPSUMJMFC',
                  access_token_key='2377938032-XwtY0uyE0b7clfqqua9fwJsXbbMOjRnEEyjzi9h',
                  access_token_secret='WGdDwcxTDhdqgqkb84lGra1S40IV8TnZ2AljP2nLvj9Of')

# %%
results_mag = api.GetSearch(
    raw_query="l=pt&q=Lu OR do OR Magalu OR Magazine OR Luiza %40magazineluiza since%3A2019-10-15 until%3A2019-10-16&result_type=recent&tweet_mode=extended&count=100")

# %%
sql_query = ""
for result in results_mag:
    data = result.__repr__().split("Created=", 1)[1].split(")", 1)[0]
    if not sql_query:
        sql_query += "    ('{:s}');\n".format(data.replace("'", "''"))
    else:
        sql_query = "    ('{:s}'),\n".format(data.replace("'", "''")) + sql_query

sql_query = "INSERT INTO magazine_tweets(content)\n" \
            "VALUES\n" + sql_query

print(sql_query)
with open('sql_magazine_tweets_query.sql', "w", encoding="utf-8") as f:
    f.write(sql_query)
# Out:
# INSERT INTO magazine_tweets(content)
# VALUES
#     ('Tue Oct 15 11:16:58 +0000 2019, Text=''@magazineluiza Magalu é basicamente zero consciência 1000% consumo.'''),
#     ('Tue Oct 15 11:19:41 +0000 2019, Text=''RT @magazineluiza: Bom dia! Hoje é #DiaDoProfessor e será o dia inteiro de homenagens! 💙 Para começar, liberei DESCONTO DE 50% em LIVROS no…'''),
#     ('Tue Oct 15 11:24:57 +0000 2019, Text=''RT @magazineluiza: Bom dia! Hoje é #DiaDoProfessor e será o dia inteiro de homenagens! 💙 Para começar, liberei DESCONTO DE 50% em LIVROS no…'''),
#     ('Tue Oct 15 11:29:35 +0000 2019, Text=''@magazineluiza Sou professora e preciso muuuuito de  um notebook novo ! Não sei quando poderei comprar um ... Me presenteia , Lu ! ❤️❤️'''),
#     ('Tue Oct 15 11:34:31 +0000 2019, Text=''RT @magazineluiza: Bom dia! Hoje é #DiaDoProfessor e será o dia inteiro de homenagens! 💙 Para começar, liberei DESCONTO DE 50% em LIVROS no…'''),
#     ('Tue Oct 15 11:39:45 +0000 2019, Text=''RT @magazineluiza: Bom dia! Hoje é #DiaDoProfessor e será o dia inteiro de homenagens! 💙 Para começar, liberei DESCONTO DE 50% em LIVROS no…'''),
#     ('Tue Oct 15 11:39:57 +0000 2019, Text=''RT @magazineluiza: Bom dia! Hoje é #DiaDoProfessor e será o dia inteiro de homenagens! 💙 Para começar, liberei DESCONTO DE 50% em LIVROS no…'''),
#     ('Tue Oct 15 11:42:57 +0000 2019, Text=''@jehtrajanno @magazineluiza Jogo do bicho então.'''),
#     ('Tue Oct 15 11:43:40 +0000 2019, Text=''RT @magazineluiza: Bom dia! Hoje é #DiaDoProfessor e será o dia inteiro de homenagens! 💙 Para começar, liberei DESCONTO DE 50% em LIVROS no…'''),
#     ('Tue Oct 15 11:48:08 +0000 2019, Text=''@andersonzezo @magazineluiza Bom dia! Você acaba de ganhar um celular novo! \nBasta comparecer a qualquer uma das lojas Magazine Luiza da sua cidade com identidade, cpf e uma conta de luz. \nPedir o seu Motorola G5 e oferecer uma doação de 850 reais, que ele é totalmente seu, sem custo adicional!!!!'''),
#     ('Tue Oct 15 12:03:26 +0000 2019, Text=''RT @magazineluiza: Bom dia! Hoje é #DiaDoProfessor e será o dia inteiro de homenagens! 💙 Para começar, liberei DESCONTO DE 50% em LIVROS no…'''),
#     ('Tue Oct 15 12:18:29 +0000 2019, Text=''@lfcrodrigues @magazineluiza A expectativa é q estenda esse tradicional bom atendimento à netshoes tbm. Pq era...affffffffffff, desgastante de mais precisar do sac deles. Só por telefone q era bom.'''),
#     ('Tue Oct 15 12:28:43 +0000 2019, Text=''@magazineluiza Cadê a confirmaçao do pedido que fiz ontem a tarde ? Qual a dificuldade ?'''),
#     ('Tue Oct 15 12:33:22 +0000 2019, Text=''@magazineluiza É uma Merda! Compramos um presente no dia 14 09 2019 para que chegasse antes do dia das crianças mas pelo visto eles gostam de enrolar os clientes! VAI TOMAR NO CÚ @magazineluiza !'''),
#     ('Tue Oct 15 12:42:15 +0000 2019, Text=''@magazineluiza Caverna do dagrão❤❤❤'''),
#     ('Tue Oct 15 12:42:33 +0000 2019, Text=''RT @magazineluiza: Bom dia! Hoje é #DiaDoProfessor e será o dia inteiro de homenagens! 💙 Para começar, liberei DESCONTO DE 50% em LIVROS no…'''),
#     ('Tue Oct 15 12:43:06 +0000 2019, Text=''Mês passado fiz uma compra no @magazineluiza e chegou em 14h \nSemana passada fiz outra compra e tá previsto pra chegar só em dezembro \nPoxa Magazine você adora iludir né'''),
#     ('Tue Oct 15 12:45:34 +0000 2019, Text=''RT @magazineluiza: Bom dia! Hoje é #DiaDoProfessor e será o dia inteiro de homenagens! 💙 Para começar, liberei DESCONTO DE 50% em LIVROS no…'''),
#     ('Tue Oct 15 12:50:59 +0000 2019, Text=''@magazineluiza Obrigado, Lu! Comprei. :'),
#     ('Tue Oct 15 13:13:31 +0000 2019, Text=''@magazineluiza hey olha essa pagina https://t.co/HgRDkn2Ih5'''),
#     ('Tue Oct 15 13:14:54 +0000 2019, Text=''@sharlesnow @magazineluiza Perfeito, só não esquece do seguro depois &lt;3'''),
#     ('Tue Oct 15 13:17:02 +0000 2019, Text=''@magazineluiza Magalu cadê o cupom de desconto'''),
#     ('Tue Oct 15 13:25:01 +0000 2019, Text=''@cec_yan @magazineluiza O poder do hábito, um do harlan Coben e vários outros kkkkk'''),
#     ('Tue Oct 15 13:33:53 +0000 2019, Text=''@magazineluiza Bom dia #Lu. Seguinte, tem alguns bugs/erros no site e eu gostaria de encaminhá-los, como devo proceder?\n#magazineluiza'''),
#     ('Tue Oct 15 13:34:28 +0000 2019, Text=''@magazineluiza Bom dia #Lu. Seguinte, tem alguns bugs/erros no site e eu gostaria de encaminhá-los, como devo proceder?\n#magazineluiza'''),
#     ('Tue Oct 15 13:42:30 +0000 2019, Text=''@magazineluiza a loja de Carpina-PE sabe muito bem ligar para oferecer cartão, mas na hora de receber ligação para tirar alguma dúvida do cliente ninguém toca no telefone.'''),
#     ('Tue Oct 15 13:51:26 +0000 2019, Text=''RT @magazineluiza: Bom dia! Hoje é #DiaDoProfessor e será o dia inteiro de homenagens! 💙 Para começar, liberei DESCONTO DE 50% em LIVROS no…'''),
#     ('Tue Oct 15 14:02:34 +0000 2019, Text=''@ismalhesilva @magazineluiza Também estou a procura de um novo televisor. Assista a este review do @Tecnoblog. Foi bem esclarecedor. https://t.co/xnWh8FJXOq'''),
#     ('Tue Oct 15 14:10:23 +0000 2019, Text=''Estes foram os resultados da semana 6 da NFL! E aí, como foi o desempenho do seu time, fã de esportes? 🏈🔥\n⠀⠀⠀⠀⠀⠀\n#NFLnaESPN oferecimento: @nacaomitsubishi, @SamsungBrasil, @Bradesco e @magazineluiza https://t.co/dYN80wigdA'''),
#     ('Tue Oct 15 14:13:07 +0000 2019, Text=''RT @magazineluiza: Já garantiram o livro pela metade do preço? 🤔 Pra comemorar o #DiaDoProfessor tem muuito livro com desconto no App do Ma…'''),
#     ('Tue Oct 15 14:13:22 +0000 2019, Text=''@magazineluiza Eu quero celular pela metade do preço 👍'''),
#     ('Tue Oct 15 14:15:51 +0000 2019, Text=''@magazineluiza Queria aproveitar o cupom do livro pro lançamento que tanto esperei. Mas vocês não tem a tumba do tirano. Das provações de Apolo, Rick riordan 😔😔'''),
#     ('Tue Oct 15 14:17:41 +0000 2019, Text=''RT @magazineluiza: Bom dia! Hoje é #DiaDoProfessor e será o dia inteiro de homenagens! 💙 Para começar, liberei DESCONTO DE 50% em LIVROS no…'''),
#     ('Tue Oct 15 14:23:57 +0000 2019, Text=''oooow recebi parabéns da Lu @magazineluiza  incrível https://t.co/oDAJ5l6Xle'''),
#     ('Tue Oct 15 14:38:35 +0000 2019, Text=''RT @magazineluiza: Bom dia! Hoje é #DiaDoProfessor e será o dia inteiro de homenagens! 💙 Para começar, liberei DESCONTO DE 50% em LIVROS no…'''),
#     ('Tue Oct 15 14:48:18 +0000 2019, Text=''@magazineluiza se tivesse com frete grátis iria ser metade do preço mesmo, mas o frete não ajuda =/'''),
#     ('Tue Oct 15 14:49:17 +0000 2019, Text=''@magazineluiza Oh Lu, tô tentandon mas seu site não ta passando.\nMe ajude aí...\nQuero cupom, depois de perder tantos. kkkk... https://t.co/gqAxOZilvx'''),
#     ('Tue Oct 15 14:51:01 +0000 2019, Text=''RT @magazineluiza: Já garantiram o livro pela metade do preço? 🤔 Pra comemorar o #DiaDoProfessor tem muuito livro com desconto no App do Ma…'''),
#     ('Tue Oct 15 14:53:16 +0000 2019, Text=''@magazineluiza Não dá pra usar o cupom nesse lu. #helpme'''),
#     ('Tue Oct 15 14:55:54 +0000 2019, Text=''@magazineluiza Lu, posso te chamar pra vc assistir a minha aula um dia?'''),
#     ('Tue Oct 15 15:00:55 +0000 2019, Text=''@magazineluiza magalu, se algum dia eu te critiquei me perdoa\nvc não tem defeitos\naaaaaaa'''),
#     ('Tue Oct 15 15:02:42 +0000 2019, Text=''@rafsoc_ @magazineluiza KKKKKKKKKKK DO NADA'''),
#     ('Tue Oct 15 15:03:17 +0000 2019, Text=''@magazineluiza Ôh Magalu, me consiga aquele cupom para eu comprar o moto one vision 🙏'''),
#     ('Tue Oct 15 15:06:03 +0000 2019, Text=''@magazineluiza A mesma coisa que eu senti quando você disse pra gente aguardar as "ofertas" do aniversário do site, iludido e frustrado'''),
#     ('Tue Oct 15 15:15:18 +0000 2019, Text=''@magazineluiza Oi Lu, tô triste na sexta passada eu ia comprar a TV LG de 50 polegadas que tava na promoção do clube da Lu. E na hora que fui pegar o cartão o preço tinha voltado o normal. Abre a promoção da TV de novo pra mim poder comprar por favor 😊😅'''),
#     ('Tue Oct 15 15:18:34 +0000 2019, Text=''RT @magazineluiza: Já garantiram o livro pela metade do preço? 🤔 Pra comemorar o #DiaDoProfessor tem muuito livro com desconto no App do Ma…'''),
#     ('Tue Oct 15 15:36:50 +0000 2019, Text=''RT @magazineluiza: Já garantiram o livro pela metade do preço? 🤔 Pra comemorar o #DiaDoProfessor tem muuito livro com desconto no App do Ma…'''),
#     ('Tue Oct 15 15:39:45 +0000 2019, Text=''@magazineluiza poxa Lu, queria aproveitar a promoção de livros no app hj, mas não tem loja aqui com esses produtos. Poxa.. também queremos que vocês vendam livros em Belém. Perdi a promoção :( e iria comprar uns 4 livros. Chateada estou!'''),
#     ('Tue Oct 15 15:41:02 +0000 2019, Text=''E aí, @magazineluiza queria só poder ter o código de rastreio do produto. Já que o link disponível no site, não mostra qual o código pra colocar no site dos correios'''),
#     ('Tue Oct 15 15:43:48 +0000 2019, Text=''@magazineluiza Ter até tem Lu, o complicado está o preço kkkk. 2.999 parcelado é osso. Vcs tiveram a promo que ele saiu por 2 099 mas acabei perdendo 😔'''),
#     ('Tue Oct 15 15:52:02 +0000 2019, Text=''RT @magazineluiza: Bom dia! Hoje é #DiaDoProfessor e será o dia inteiro de homenagens! 💙 Para começar, liberei DESCONTO DE 50% em LIVROS no…'''),
#     ('Tue Oct 15 16:02:27 +0000 2019, Text=''RT @magazineluiza: Bom dia! Hoje é #DiaDoProfessor e será o dia inteiro de homenagens! 💙 Para começar, liberei DESCONTO DE 50% em LIVROS no…'''),
#     ('Tue Oct 15 16:02:58 +0000 2019, Text=''RT @magazineluiza: Vocês eram daqueles que comemoravam e depois não sabiam do sobre o que escrever? 🤔 #DiaDoProfessor https://t.co/3bz4ZNPJ…'''),
#     ('Tue Oct 15 16:10:57 +0000 2019, Text=''Ei @americanascom! Cancelaram meu cashback do @useamedigital na promoção bugada do domingo pq? Só a @magazineluiza pra cumprir os pedidos mesmo, vou continuar comprando somente com eles viu!?'''),
#     ('Tue Oct 15 16:13:22 +0000 2019, Text=''RT @magazineluiza: Vocês eram daqueles que comemoravam e depois não sabiam do sobre o que escrever? 🤔 #DiaDoProfessor https://t.co/3bz4ZNPJ…'''),
#     ('Tue Oct 15 16:22:07 +0000 2019, Text=''acho que roubaram meu pedido do @magazineluiza  na transportadora so pode . Previsão era dia 09 e ate agora NADA'''),
#     ('Tue Oct 15 16:25:28 +0000 2019, Text=''esse cupom de 50% em livros do @magazineluiza meudeusu eu jurei q não ia mais comprar livro esse ano e já botei 5 no carrinho...'''),
#     ('Tue Oct 15 16:32:32 +0000 2019, Text=''A @magazineluiza faz mais pelo combate a violência contra a mulher do que o (des'),
#     ('Tue Oct 15 16:46:45 +0000 2019, Text=''@americanascom Ei @americanascom! Cancelaram meu cashback do @useamedigital na promoção bugada do domingo pq? Só a @magazineluiza pra cumprir os pedidos mesmo, vou continuar comprando somente com eles viu!?'''),
#     ('Tue Oct 15 16:59:42 +0000 2019, Text=''RT @magazineluiza: Vocês eram daqueles que comemoravam e depois não sabiam do sobre o que escrever? 🤔 #DiaDoProfessor https://t.co/3bz4ZNPJ…'''),
#     ('Tue Oct 15 17:13:34 +0000 2019, Text=''aaaa tô muito feliz, consegui fazer o pagamento do meu celular ontem, ontem mesmo foi enviado e tá em rota de entrega. @magazineluiza sempre com os melhores preços, frete e qualidade dos produtos. Recomendo'''),
#     ('Tue Oct 15 17:38:30 +0000 2019, Text=''RT @magazineluiza: Bom dia! Hoje é #DiaDoProfessor e será o dia inteiro de homenagens! 💙 Para começar, liberei DESCONTO DE 50% em LIVROS no…'''),
#     ('Tue Oct 15 17:39:17 +0000 2019, Text=''Não recomendo comprar online nas @CasasBahia. Precisa comer muito arroz com feijão pra chegar perto da @magazineluiza que é muito mais ágil no processamento e entrega do pedido.'''),
#     ('Tue Oct 15 18:11:30 +0000 2019, Text=''@magazineluiza Explica pro provo que o jogo voltou agora Lu.'''),
#     ('Tue Oct 15 18:28:01 +0000 2019, Text=''Pow  Lu @magazineluiza como faz pra vc parara com essa amizade tóxica comigo ? https://t.co/jdJniddNFs'''),
#     ('Tue Oct 15 18:34:56 +0000 2019, Text=''@magazineluiza Magalu meu pedido é 7736500505404583'''),
#     ('Tue Oct 15 18:41:32 +0000 2019, Text=''mano eu não consigo me candidatar na magazine luiza nem com uma porra.. toda hora aquela droga de 99jobs diz que preciso de uma formação cadastrada quando eu já coloquei milhões de vezes.. @magazineluiza sai da 99jobs e vai pro https://t.co/81OmsDFWGj pelo amor de zeus'''),
#     ('Tue Oct 15 18:44:03 +0000 2019, Text=''@magazineluiza como sempre, surpreendendo !!! \n\nComo amo essa empresa !!! #MGLU3 #Magalu 🚀 https://t.co/5237Tk9cvQ'''),
#     ('Tue Oct 15 18:45:37 +0000 2019, Text=''Em comemoração ao Dia do Professor recebi essa caixa com alguns presentes do @magazineluiza e da Lu. \n.\n. \nMuito feliz em compartilhar com vocês e relembrar a importância da leitura na formação das nossas bases como… https://t.co/9WamcbUUxl'''),
#     ('Tue Oct 15 18:46:22 +0000 2019, Text=''@magazineluiza uma vitória do cruzeirao criminoso 🙏'''),
#     ('Tue Oct 15 18:47:30 +0000 2019, Text=''@magazineluiza  me responde DM, meu pedido desde o dia 09 .. Foi roubado ou algo do tipo ?'''),
#     ('Tue Oct 15 18:49:30 +0000 2019, Text=''Só pra deixar registrado pra posteridade que eu AMO a Lu @magazineluiza e já quero ela como minha melhor amiga. Adoro as mensagens no whats 😘🥰'''),
#     ('Tue Oct 15 18:52:20 +0000 2019, Text=''@lucasparrini @magazineluiza A Lu me mandou DM, espero que resolva'''),
#     ('Tue Oct 15 18:54:57 +0000 2019, Text=''@VOliveira_PST @sigaNetshoes @magazineluiza Eita, todo mundo com o mesmo problema. O meu produto era um tênis da Ecko Court. Eu já fiz a reclamação no https://t.co/h41NxCgMNC já que na DM não respondem e no chat pediram para eu entrar em contato mais tarde já que o sistema estava fora do ar.'''),
#     ('Tue Oct 15 18:55:14 +0000 2019, Text=''@magazineluiza Cadê o iPhone Xr na promoção, Lu? 🙏🏾'''),
#     ('Tue Oct 15 18:55:46 +0000 2019, Text=''@magazineluiza quando teremos a honra, de termos lojas da Magazine Luiza aqui em Brasília?'''),
#     ('Tue Oct 15 18:59:22 +0000 2019, Text=''@magazineluiza que palhaçada e essa de liberar cupom e não ter o box do Harry Potter pra comprar??'''),
#     ('Tue Oct 15 19:14:14 +0000 2019, Text=''minha estante ainda não chegou @magazineluiza..... me deixar na mão desse jeito, lu? poxa'''),
#     ('Tue Oct 15 19:23:29 +0000 2019, Text=''@magazineluiza Disse q não era possível completar a compra. Tirei um livro do carrinho e rolou 💪🏾'''),
#     ('Tue Oct 15 19:26:15 +0000 2019, Text=''@magazineluiza Sim já sabia, o q houve foi uma GRANDE falta de consideração,pois só me avisaram do acontecido depois de eu ter ligado DUAS VEZ perguntando sobre o produto em atraso.Segundo relato do atendente,este é um ERRO RECORRENTE. No fim,o PREJUDICADO será o cliente. NOTA ZERO 👏👏 TRISTE!'''),
#     ('Tue Oct 15 19:28:52 +0000 2019, Text=''@arturramalho @sigaNetshoes @magazineluiza Pois é, o chat está com problemas, por DM ninguém responde. O consumidor que se vire p resolver o problema. Era cliente antigo do site, mas está foi a última vez que compro. Inclusive, já realizei a compra do produto da @centauroesporte e por um valor menor.'''),
#     ('Tue Oct 15 19:53:26 +0000 2019, Text=''@magazineluiza consegui por esse link e espero receber uma ligação dizendo que tenho uma entrevista e espero ser contratada haha me ajuda lu tenho conta pra pagar'''),
#     ('Tue Oct 15 20:13:12 +0000 2019, Text=''@magazineluiza poxa Lu, um cuponzinho pra geladeira hoje seria incrível viu. Aproveitar q meu Aniversário tá chegando'''),
#     ('Tue Oct 15 20:14:27 +0000 2019, Text=''RT @magazineluiza: Prioridades, gente! Tem que cuidar do material, né? 😉 rs #DiaDoProfessor 💙 https://t.co/3IpeQVqKeX'''),
#     ('Tue Oct 15 20:16:49 +0000 2019, Text=''Primeira e última vez que compro pelo app da magalu da outra vez foi o estresse da troca na loja física e agora o truque da entrega no dia 15. @magazineluiza  a menina que lhe tira a esperança #magoada'''),
#     ('Tue Oct 15 20:17:38 +0000 2019, Text=''@magazineluiza minha mãe encapava os meus com sacola de supermercado.  Cada ano eu tinha q escolher uma campanha diferente:\n\n- nome e contato do estabelecimento\n- obrigado pela preferência\n- proteja o meio ambiente\n- desaparecido'''),
#     ('Tue Oct 15 20:29:57 +0000 2019, Text=''@juli4cursi @magazineluiza Aconteceu a mesma coisa comigo, só que com a Americanas. Dezembro faz 1 ano, e ainda sigo com processo contra eles. \nObs: eles não resolveram nada e ainda demoraram uns 5 meses para fazer a devolução do valor do notebook.'''),
#     ('Tue Oct 15 20:42:08 +0000 2019, Text=''RT @magazineluiza: Prioridades, gente! Tem que cuidar do material, né? 😉 rs #DiaDoProfessor 💙 https://t.co/3IpeQVqKeX'''),
#     ('Tue Oct 15 20:42:18 +0000 2019, Text=''@magazineluiza me responde magalu pelamor'''),
#     ('Tue Oct 15 21:06:15 +0000 2019, Text=''@magazineluiza Lu, eu sou professor e quero um cupom pra comprar uma caixinha JBL pra dar aula! Me ajuda!'''),
#     ('Tue Oct 15 21:10:39 +0000 2019, Text=''ô @magazineluiza me da um cupom de desconto ai pra renovar as cadeiras do home office, minha mae ta com dor na coluna e eu no bolso'''),
#     ('Tue Oct 15 21:10:51 +0000 2019, Text=''@magazineluiza eu sou ansioso dona lu https://t.co/6K4ZPVFyXL'''),
#     ('Tue Oct 15 21:17:27 +0000 2019, Text=''@magazineluiza Ai @magazineluiza comprei vários livros que eu queria a tanto tempo, graças a promo do app. Agora mau posso esperar pra fazer parte do clube da lu 😁'''),
#     ('Tue Oct 15 21:37:52 +0000 2019, Text=''ia comprar todos os móveis da minha casa na loja da @magazineluiza já que na internet os preços estavam sensacionais... cheguei na loja tava praticamente o dobro do valor, quase chorei e comprei só a máquina lava e seca'''),
#     ('Tue Oct 15 21:41:15 +0000 2019, Text=''@magazineluiza Lu.. não tá disponível em nenhuma loja em Belém.. é o que o app me diz. Acredito que as lojas daqui de Belém não vendem. Apenas coisas para a casa. Tentem abranger nós amantes da leitura. Por favorzinho ☹️💜'''),
#     ('Tue Oct 15 21:51:10 +0000 2019, Text=''@magazineluiza Comprei minha impressora ontem na Magalu, mas queria mesmo era um emprego lá :('''),
#     ('Tue Oct 15 22:17:41 +0000 2019, Text=''@juli4cursi @magazineluiza decepcionada magalu @magazineluiza cadê o retorno????'''),
#     ('Tue Oct 15 22:23:21 +0000 2019, Text=''@magazineluiza Quando vou procurar um ar condicionado, por exemplo, e organizo por menor preço aparece um monte de peças para manutenção, que não é objeto de interesse do cidadão comum. Arruma um jeito de separar as peças por um filtro aí qualquer, que ajuda.'''),
#     ('Tue Oct 15 22:34:12 +0000 2019, Text=''@iurybsantos @magazineluiza TIRA O PÉ DO MEU TCC MAGAZINE LUIZA'''),
#     ('Tue Oct 15 22:43:56 +0000 2019, Text=''Gritando alto aqui,  minha filha de 9 anos baixou o app @magazineluiza no celular dela pra poder fazer compras.\nPerguntei como ela vai pagar,  ela disse que é só pelo prazer de encher o carrinho e ser rica por instantes 😂\nEla é tão eu 😅\n#Magalu https://t.co/DbflKjJVLF''');

# %%
results_inter = api.GetSearch(
    raw_query="q=Banco Inter \"banco inter\" lang%3Apt since%3A2019-10-15 until%3A2019-10-16&result_type=recent&tweet_mode=extended&count=100")

# %%
sql_query = ""
for result in results_inter:
    data = result.__repr__().split("Created=", 1)[1].split(")", 1)[0]
    if not sql_query:
        sql_query += "    ('{:s}');\n".format(data.replace("'", "''"))
    else:
        sql_query = "    ('{:s}'),\n".format(data.replace("'", "''")) + sql_query

sql_query = "INSERT INTO inter_tweets(content)\n" \
            "VALUES\n" + sql_query

print(sql_query)
with open('sql_inter_tweets_query.sql', "w", encoding="utf-8") as f:
    f.write(sql_query)
# Out:
# INSERT INTO inter_tweets(content)
# VALUES
#     ('Tue Oct 15 04:07:53 +0000 2019, Text=''E caso o seu banco empurre taxas FAÇA A PORTABILIDADE IMEDIATAMENTE\nO Banco Inter tem TED, SAQUES gratuitos e ilimitado \nO Nubank já é TED ilimitado https://t.co/gNezt6r51o'''),
#     ('Tue Oct 15 04:12:46 +0000 2019, Text=''RT @VolpiM1lGr4u: O Banco Inter fez uma promoção de "assista o jogo dentro do campo" pro Tiago Volpi? https://t.co/6owrtACbhV'''),
#     ('Tue Oct 15 04:45:48 +0000 2019, Text=''RT @VolpiM1lGr4u: O Banco Inter fez uma promoção de "assista o jogo dentro do campo" pro Tiago Volpi? https://t.co/6owrtACbhV'''),
#     ('Tue Oct 15 06:06:18 +0000 2019, Text=''RT @VolpiM1lGr4u: O Banco Inter fez uma promoção de "assista o jogo dentro do campo" pro Tiago Volpi? https://t.co/6owrtACbhV'''),
#     ('Tue Oct 15 09:08:05 +0000 2019, Text=''Banco Inter dispara mais de 7% com conversas para parceria com a Uber no Brasil https://t.co/I9LSfLv26J'''),
#     ('Tue Oct 15 09:38:18 +0000 2019, Text=''RT @ForbesBR: Banco Inter e Uber negociam parceria: https://t.co/Oo53z1bJqJ https://t.co/4pO2dS4Qtj'''),
#     ('Tue Oct 15 09:48:38 +0000 2019, Text=''Indiquei o Banco Inter  para o @paulovecba ele fez o cartão e faz dois meses que ele entra no chat e dizem que o cartão “tá chegando” \nAlô @Bancointer'''),
#     ('Tue Oct 15 10:17:14 +0000 2019, Text=''@dondomenico1940 @Guilher82516979 @FEBRABAN @Bancointer E a taxa de juros? Banco inter continua sendo banco, amigo.'''),
#     ('Tue Oct 15 10:36:23 +0000 2019, Text=''RT @VolpiM1lGr4u: O Banco Inter fez uma promoção de "assista o jogo dentro do campo" pro Tiago Volpi? https://t.co/6owrtACbhV'''),
#     ('Tue Oct 15 10:56:27 +0000 2019, Text=''Sabe esse banco Inter? \n\nMuito legal, muito bonitinho, baratinho...\n\nMas é um tal de dar erro nas transferências pra outros bancos que só Jesus na causa viu...'''),
#     ('Tue Oct 15 10:56:41 +0000 2019, Text=''@pancarodrigues @Bancointer Banco inter é foda 🧡'''),
#     ('Tue Oct 15 11:33:00 +0000 2019, Text=''Com as taxas de juros caindo, a expectativa é de um destravamento do crédito no Brasil, favorecendo os bancos. Com isso as ações do Bradesco(BBDC4'),
#     ('Tue Oct 15 11:44:55 +0000 2019, Text=''@ElvisLeao1918 Ei, Elvis! O Banco Inter ainda não é credenciado como Banco Pagador, por isso, no momento não temos convênio para receber este benefício pela conta digital, combinado?'''),
#     ('Tue Oct 15 12:09:14 +0000 2019, Text=''@LorenzonLarissa Ah primeiramente vc precisa de uma corretora né\neu uso o home broker do banco Inter mesmo q cai tudo na minha conta e nao tem taxa de custódia\ndepois disso é literalmente estudar todo dia sobre as ações\neu invisto em fundos imobiliarios também'''),
#     ('Tue Oct 15 12:21:18 +0000 2019, Text=''@CATTO172 Olá! Como a conta do Banco Inter foi a conta de destino, orientamos que verifique esta informação com o banco de origem da transação, certinho? Estamos sempre à disposição!'''),
#     ('Tue Oct 15 12:36:11 +0000 2019, Text=''@josuenunes @leonardo_61 @renoirvieira @cafecomferri Eu discordo dele, pois os bancos digitais só oferecem uma interface que os bancões já ofereciam. A do NuBank é bem diferente mas os serviços são limitados, facilita. A do Banco Inter é tão ruim qto a dos bancões.'''),
#     ('Tue Oct 15 12:41:59 +0000 2019, Text=''Atendimento digital do banco Inter é péssimo'''),
#     ('Tue Oct 15 12:54:34 +0000 2019, Text=''O mercado se surpreendeu ontem com a possível parceria entre Banco Inter e Uber.\nCom a chegada do Softbank, alertamos que isso poderia acontecer. Inclusive, falei isso no Stock Pills no início de agosto.\n#BIDI11 https://t.co/mSUJnqHiUT'''),
#     ('Tue Oct 15 13:00:52 +0000 2019, Text=''@o_gabsferreira Não pague por tarifas dos bancos tradicionais (plano essencial'),
#     ('Tue Oct 15 13:07:04 +0000 2019, Text=''@StephanieUmeda @maripedrosa19 Segue imagens da Stephanie com os migos espalhando a palavra do Banco Inter https://t.co/4CUNWqTDYd'''),
#     ('Tue Oct 15 13:30:54 +0000 2019, Text=''RT @l3tisia: eu sou testemunha de Telegram, Banco Inter e agora de Xiaomi'''),
#     ('Tue Oct 15 13:42:04 +0000 2019, Text=''RT @l3tisia: eu sou testemunha de Telegram, Banco Inter e agora de Xiaomi'''),
#     ('Tue Oct 15 13:45:40 +0000 2019, Text=''RT @daltozo: O mercado se surpreendeu ontem com a possível parceria entre Banco Inter e Uber.\nCom a chegada do Softbank, alertamos que isso…'''),
#     ('Tue Oct 15 13:50:23 +0000 2019, Text=''RT @VolpiM1lGr4u: O Banco Inter fez uma promoção de "assista o jogo dentro do campo" pro Tiago Volpi? https://t.co/6owrtACbhV'''),
#     ('Tue Oct 15 13:53:31 +0000 2019, Text=''Eu quero ser estagiário do estagiário do banco inter as vezes https://t.co/iCW0q7IGgm'''),
#     ('Tue Oct 15 14:22:13 +0000 2019, Text=''@SPFCBancoInter @SaoPauloFC Eu te amo banco Inter!!!!'''),
#     ('Tue Oct 15 14:24:04 +0000 2019, Text=''@Elainenany_ @GiilGouveia Uma vez fui de graça com o banco Inter'''),
#     ('Tue Oct 15 14:24:24 +0000 2019, Text=''RT @l3tisia: eu sou testemunha de Telegram, Banco Inter e agora de Xiaomi'''),
#     ('Tue Oct 15 14:27:01 +0000 2019, Text=''@johnny_souto @BTGPDigital @gpass0s Outra opção é o Banco Inter, com o qual eu nunca tive problemas. Porém, devo dizer que recentemente andei vendo muitas reclamações a respeito do atendimento deles. Cresceu demais em pouco tempo e parece que não ter se estruturado o suficiente.'''),
#     ('Tue Oct 15 14:28:00 +0000 2019, Text=''@imcristovao @Caixa @Bancointer fila? isso ainda existe? dps que entrei no banco inter tenho nem ideia o que é isso'''),
#     ('Tue Oct 15 14:29:05 +0000 2019, Text=''RT @VolpiM1lGr4u: O Banco Inter fez uma promoção de "assista o jogo dentro do campo" pro Tiago Volpi? https://t.co/6owrtACbhV'''),
#     ('Tue Oct 15 14:29:38 +0000 2019, Text=''RT @l3tisia: eu sou testemunha de Telegram, Banco Inter e agora de Xiaomi'''),
#     ('Tue Oct 15 14:29:51 +0000 2019, Text=''@Bancointer Ao invés de se preocupar com dentes, o Banco Inter deveria rever sua política de limites dos cartões de crédito. Uma crítica construtiva vale mais do que 1.000 elogios!'''),
#     ('Tue Oct 15 14:36:28 +0000 2019, Text=''@GordoGeek @Wardz_de_souzA Outro dia o banco inter deixou vazar dados de correntistas. Vivo dizendo que essas fintechs não estão no mesmo nível dos bancões.'''),
#     ('Tue Oct 15 14:40:38 +0000 2019, Text=''RT @l3tisia: eu sou testemunha de Telegram, Banco Inter e agora de Xiaomi'''),
#     ('Tue Oct 15 14:50:03 +0000 2019, Text=''KKKKKKKKKKKKKKKKKK CRL O ESTAGIARIO DESSE BANCO INTER É FODA DMS https://t.co/aLcwkH6UVU'''),
#     ('Tue Oct 15 14:50:42 +0000 2019, Text=''RT @VolpiM1lGr4u: O Banco Inter fez uma promoção de "assista o jogo dentro do campo" pro Tiago Volpi? https://t.co/6owrtACbhV'''),
#     ('Tue Oct 15 15:00:09 +0000 2019, Text=''RT @VolpiM1lGr4u: O Banco Inter fez uma promoção de "assista o jogo dentro do campo" pro Tiago Volpi? https://t.co/6owrtACbhV'''),
#     ('Tue Oct 15 15:01:55 +0000 2019, Text=''Além disso, para o Banco Inter, acessar a base de motoristas do Uber e os usuários do aplicativo como clientes em potencial deve acelerar o seu processo de expansão. https://t.co/vvJSFRob1E'''),
#     ('Tue Oct 15 15:07:54 +0000 2019, Text=''mano, banco inter me disponibilizou 3x mais do que eu esperava. tô em choque.'''),
#     ('Tue Oct 15 15:11:22 +0000 2019, Text=''#principaisassuntosdodia\nVendas no varejo crescem em setembro\nhttps://t.co/6OYDOEQNtg\n\nBanco Inter e Uber em negociações para estabelecer parceria de serviços financeiros\nhttps://t.co/tRoWqRZVPu https://t.co/NXDhTv7H9v'''),
#     ('Tue Oct 15 15:22:26 +0000 2019, Text=''2'),
#     ('Tue Oct 15 15:43:38 +0000 2019, Text=''O Banco Inter é perfeito pra mim desde que abri a conta, mas as pessoas que foram atingidas por falhas no sistema têm opiniões diferentes. Não tem como padronizar experiência e eu só posso falar com base na minha. Para + dicas de bancos digitais, consulte @JCSerraCampos.'''),
#     ('Tue Oct 15 15:47:44 +0000 2019, Text=''@Bancointer Banco inter me ajuda mandei msg no chat'''),
#     ('Tue Oct 15 15:50:28 +0000 2019, Text=''@SPFCBancoInter @SaoPauloFC Quero o estagiário do banco inter no sp já !!!!'''),
#     ('Tue Oct 15 15:52:07 +0000 2019, Text=''O atendimento do banco inter é muito ruim, ngm merece'''),
#     ('Tue Oct 15 16:04:24 +0000 2019, Text=''Pensando seriamente em fazer uma conta no banco inter só pq eles são foda como patrocinador'''),
#     ('Tue Oct 15 16:08:14 +0000 2019, Text=''RT @VulgoWalter: O atendimento do banco inter é muito ruim, ngm merece'''),
#     ('Tue Oct 15 16:27:20 +0000 2019, Text=''RT @trademapapp: As units do Banco Inter (BIDI11'),
#     ('Tue Oct 15 16:32:19 +0000 2019, Text=''@ancapisa Banco sofisa direto tem investimentos de no minimo 1 real.\nBanco Inter tem de 100 reais.\nNuconta rende absolutamente qqr quantia parada lá.\nDeve haver mais opções, essas são as que eu uso.'''),
#     ('Tue Oct 15 16:36:49 +0000 2019, Text=''@ancapisa Claro que dá, só depende do meio. Eu investia pelo Banco Inter e era 100 reais o mínimo, com 100% do CDI e liquidez diária\nLembro que cheguei a testar a Easy Invest e a XP, mas não sei te informar como tá agora\nDá uma olhada na tabela das corretoras e dos bancos, tem como sim'''),
#     ('Tue Oct 15 16:37:38 +0000 2019, Text=''RT @daltozo: O mercado se surpreendeu ontem com a possível parceria entre Banco Inter e Uber.\nCom a chegada do Softbank, alertamos que isso…'''),
#     ('Tue Oct 15 16:38:36 +0000 2019, Text=''banco inter tem atendimento de chat pra quê se cada resposta demora 20 minutos pra acontecer???///'''),
#     ('Tue Oct 15 16:53:11 +0000 2019, Text=''RT @l3tisia: eu sou testemunha de Telegram, Banco Inter e agora de Xiaomi'''),
#     ('Tue Oct 15 16:54:33 +0000 2019, Text=''@cascat1nha tenho o cartão desse banco inter e nunca nem usei.'''),
#     ('Tue Oct 15 16:58:03 +0000 2019, Text=''@Bancointer Boa Tarde Banco inter, me chamo Rodrigo tenho conta ativa e indiquei o banco para minha sobrinha e ela não tá conseguindo finalizar o cadastro dela, chegou um e-mail dizendo que os documentos que ela mandou está danificado, sendo que não está. Como fazemos???'''),
#     ('Tue Oct 15 17:03:43 +0000 2019, Text=''@viniciuss_vsm @Viniciusgabrzx já falei, banco inter total\n\ndaqui a pouco teremos DANI ALVES DEBOCHADO'''),
#     ('Tue Oct 15 17:22:21 +0000 2019, Text=''boa tarde estagi do banco inter curtiu minha resposta a um tweet deles'''),
#     ('Tue Oct 15 17:36:19 +0000 2019, Text=''@JimmBat1 @_athamiris #VemPraNossaRevolução, Thamiris! A Conta Digital do Banco Inter é a solução ideal para você economizar tempo e dinheiro, além de fazer tudo que precisar pelo App ou IB! Você encontra mais informações em: https://t.co/v3JORZFw66\nSe tiver dúvidas, #contacomagente 😉'''),
#     ('Tue Oct 15 17:51:24 +0000 2019, Text=''@HelenFernanda Em 99% do tempo o Banco Inter funciona, o problema é que quando falha, falha muito feio.\nEu estou usando o Banco Next e mantendo dinheiro nos dois.'''),
#     ('Tue Oct 15 17:54:20 +0000 2019, Text=''RT @l3tisia: eu sou testemunha de Telegram, Banco Inter e agora de Xiaomi'''),
#     ('Tue Oct 15 18:01:17 +0000 2019, Text=''@xaynnne quem que nega imposto mas paga taxa pra branco? tem que ser muito idiota, banco inter, nubank e next ta ae pra que porra'''),
#     ('Tue Oct 15 18:05:48 +0000 2019, Text=''RT @VolpiM1lGr4u: O Banco Inter fez uma promoção de "assista o jogo dentro do campo" pro Tiago Volpi? https://t.co/6owrtACbhV'''),
#     ('Tue Oct 15 18:23:48 +0000 2019, Text=''@SPFCBancoInter Parabéns Banco Inter, crescendo com o SPFC!!'''),
#     ('Tue Oct 15 18:41:51 +0000 2019, Text=''@Bancointer Obrigada mas pela central ninguém conseguiu tb me ajudar se quiser consultem o histórico lá , o banco inter nao consegue fazer uma simples alteração de limite de ted, apenas daqui 15 dias uma nova tentativa , inflexibilidade que vai fazer com que eu perca negócios importantes'''),
#     ('Tue Oct 15 18:51:46 +0000 2019, Text=''banco inter tem o melhor estagiário https://t.co/LANmyGB95o'''),
#     ('Tue Oct 15 18:56:42 +0000 2019, Text=''@dhafne_tomaz @SPFCBancoInter @MinutoSpfc Nesse momento que a vontade de ser estagiário no banco inter só aumenta kkkkkkkkkkk'''),
#     ('Tue Oct 15 19:20:28 +0000 2019, Text=''Acabei de ficar sabendo que meus irmãos fizeram conta no banco inter para "investir" e "ganhar dinheiro"\nO que eu estou fazendo de erradooOOOOOooooOOo???????'''),
#     ('Tue Oct 15 19:27:29 +0000 2019, Text=''Banco Inter, Buser, MadeiraMadeira...'''),
#     ('Tue Oct 15 19:35:06 +0000 2019, Text=''RT @viniciuss_vsm Esquema Banco Inter https://t.co/h57gC95iDW'''),
#     ('Tue Oct 15 19:46:12 +0000 2019, Text=''@SPFCBancoInter @MinutoSpfc @dhafne_tomaz @AvilaLe1_ Banco inter tá com a camisa 10 e a faixa em, que isso kkkkkk'''),
#     ('Tue Oct 15 19:46:20 +0000 2019, Text=''todo mundo falando que o banco inter é melhor que o nubank, bom @Bancointer conta comigo para tudo'''),
#     ('Tue Oct 15 20:00:27 +0000 2019, Text=''RT @thegreatels: E caso o seu banco empurre taxas FAÇA A PORTABILIDADE IMEDIATAMENTE\nO Banco Inter tem TED, SAQUES gratuitos e ilimitado \nO…'''),
#     ('Tue Oct 15 20:01:42 +0000 2019, Text=''Banco Inter dispara por conversas sobre parceria com a Uber\n#SpaceMoney\n\nhttps://t.co/VX4hcdUD8X'''),
#     ('Tue Oct 15 20:06:34 +0000 2019, Text=''Uber estaria estudando parceria com Banco Inter no Brasil \nhttps://t.co/wZ4QQ59p6z https://t.co/n7hLfOvBKW'''),
#     ('Tue Oct 15 20:07:36 +0000 2019, Text=''RT @ComputerworldBR: Uber estaria estudando parceria com Banco Inter no Brasil \nhttps://t.co/wZ4QQ59p6z https://t.co/n7hLfOvBKW'''),
#     ('Tue Oct 15 20:12:18 +0000 2019, Text=''Sei lá o banco Inter mané'''),
#     ('Tue Oct 15 20:16:01 +0000 2019, Text=''@gilmarpmal @ssupergay @nubank @Bancointer Gilmar deixa eu te explicar uma coisa, o banco inter ainda existe essa cobrança mas o inter paga essa taxa, consequentemente parecendo que seja gratuito, pra gente é gratuito mas pro inter não...'''),
#     ('Tue Oct 15 20:20:53 +0000 2019, Text=''eu odeio o banco inter puta que pariu'''),
#     ('Tue Oct 15 20:28:20 +0000 2019, Text=''@idkpaulo_ Já ouvi falar bem, mas nunca usei. Uso o Banco Inter...'''),
#     ('Tue Oct 15 20:31:21 +0000 2019, Text=''RT @l3tisia: eu sou testemunha de Telegram, Banco Inter e agora de Xiaomi'''),
#     ('Tue Oct 15 20:51:00 +0000 2019, Text=''@dgodj Ei! O Intersaque é um serviço fácil e simplificado de realizar saques nos ATMs do Banco Inter, através de um código gerado pelo próprio aplicativo. Atualmente nossos ATMs estão disponíveis apenas em Belo Horizonte e São Paulo!'''),
#     ('Tue Oct 15 20:51:47 +0000 2019, Text=''🤑 RENOVAÇÃO DO BANCO INTER\n\nCom ótima relação entre empresa/clube/torcida, TODOS NÓS esperamos a renovação do acordo com aumento do período e valores. https://t.co/DrB28iET60'''),
#     ('Tue Oct 15 20:52:36 +0000 2019, Text=''@googlebrasil pelo amor de deus google, vc fizeram o acordo só com bancos tradicionais, vc uma imensa empresa digital, pq tbm nao inseriram o banco inter, o nubank, o c6 bank, o pagbank, ou seja um banco digital, esse bancos ai cobram muito, é muito burocrático; vamos add bancos digitais ai!!!'''),
#     ('Tue Oct 15 20:53:53 +0000 2019, Text=''@googlebrasil faltou sair da mafia dos bancos tradicionais que cobram muito dinheiro pra manter a conta, por favor faça acordo tbm com bancos digitais, banco inter, nu conta, c6 bank e outros....'''),
#     ('Tue Oct 15 20:58:19 +0000 2019, Text=''@SkullBlondie banco inter kkkk'''),
#     ('Tue Oct 15 21:05:44 +0000 2019, Text=''@SPFCBancoInter @Bancointer Banco Inter que tal colocar as cores do são Paulo no ônibus ?'''),
#     ('Tue Oct 15 21:07:59 +0000 2019, Text=''RT @ComputerworldBR: Uber estaria estudando parceria com Banco Inter no Brasil \nhttps://t.co/wZ4QQ59p6z https://t.co/n7hLfOvBKW'''),
#     ('Tue Oct 15 21:13:45 +0000 2019, Text=''@Bancointer ATENÇÃO BANCO INTER ALERTA ESTÃO MANDANDO ESTAS MENSAGENS PARA OS CLIENTES!!!!!! https://t.co/Ln2jlCOkdJ'''),
#     ('Tue Oct 15 21:19:53 +0000 2019, Text=''@SkullBlondie Banco Inter ou Nubank, tenho os dois e não tem do que reclamar, resolve tudo bem rápido e a qualquer hora.'''),
#     ('Tue Oct 15 21:21:36 +0000 2019, Text=''Sera que o Banco Inter quer me patrocinar e me levar pra ver o SP pelo Brasil https://t.co/b8VQJm4mRV'''),
#     ('Tue Oct 15 21:28:03 +0000 2019, Text=''RT @spfcguiih: 🤑 RENOVAÇÃO DO BANCO INTER\n\nCom ótima relação entre empresa/clube/torcida, TODOS NÓS esperamos a renovação do acordo com aum…'''),
#     ('Tue Oct 15 21:34:08 +0000 2019, Text=''RT @l3tisia: eu sou testemunha de Telegram, Banco Inter e agora de Xiaomi'''),
#     ('Tue Oct 15 21:52:24 +0000 2019, Text=''@CarolValgas_ Pode serr, tem o banco inter também se voce n conseguir'''),
#     ('Tue Oct 15 21:56:37 +0000 2019, Text=''@kyliepwr olha amg, débito quase ctz q ele é, eu já peguei banco inter e nubank e os dois são, next tbm é e eu não sei mas acho q vc precisa talvez receber algum tipo de renda pra poder desbloquear o crédito, tenta dar uma olhada nos termos do cartão ou na internet msm'''),
#     ('Tue Oct 15 22:08:04 +0000 2019, Text=''@sallinffc Tem vários q nem o nubank, tem o next, banco inter, pag'''),
#     ('Tue Oct 15 22:20:19 +0000 2019, Text=''@inejsknife sim amiga!!! acredito que ele e o banco inter são as melhores opções em cartões no momento'''),
#     ('Tue Oct 15 22:22:38 +0000 2019, Text=''banco Inter recusando cartão de crédito pra mim, que arrombado, agr quero meus 60 centavos q eu investi no banco'''),
#     ('Tue Oct 15 22:35:07 +0000 2019, Text=''RT @js_neeto: RT @viniciuss_vsm Esquema Banco Inter https://t.co/h57gC95iDW'''),
#     ('Tue Oct 15 22:42:00 +0000 2019, Text=''Para conta PJ: Banco Inter ou Neon? Inter me parece melhor mas precisa de convite, como faço isso? HIAAHUA''');
